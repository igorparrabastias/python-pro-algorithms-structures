# %% [markdown]
# # Ejercicio: Optimización de Procesos de Negocio
#
# - **Mapa mental:** Este mapa incluye pasos como la identificación de ineficiencias a través de sesiones de brainstorming, análisis de datos, y feedback de clientes, seguido de estrategias de mejora como la automatización de tareas, capacitación y desarrollo, y reingeniería de procesos. Finalmente, se aborda la implementación y el seguimiento con un plan detallado y monitoreo continuo.
#
# [https://imgr.whimsical.com/thumbnails/2LoEKCwGx3oyNMktBqECVQ/PAJiKdKDasHKDSz9Kw76Ci](https://imgr.whimsical.com/thumbnails/2LoEKCwGx3oyNMktBqECVQ/PAJiKdKDasHKDSz9Kw76Ci)
#
# Este mapa incluye pasos como la identificación de ineficiencias a través de sesiones de brainstorming, análisis de datos, y feedback de clientes, seguido de estrategias de mejora como la automatización de tareas, capacitación y desarrollo, y reingeniería de procesos. Finalmente, se aborda la implementación y el seguimiento con un plan detallado y monitoreo continuo.
#
# - **pseudo-código**: Para desarrollar una solución automatizada que mejore un proceso de negocio, primero identificaremos un proceso genérico que comúnmente requiere optimización, como el proceso de aprobación de solicitudes dentro de una organización. Este proceso a menudo involucra múltiples pasos, desde la recepción de la solicitud hasta su aprobación final, y puede beneficiarse significativamente de la automatización, especialmente en términos de integración con sistemas existentes y manejo de datos.
#
#     ```
#     funcion iniciarProcesoDeAprobacion(solicitud) {
#       // Paso 1: Validar la solicitud
#       si no esValida(solicitud) {
#         retornar "Solicitud inválida"
#       }

# %%
// Paso 2: Registrar la solicitud en el sistema
idSolicitud = registrarSolicitudEnSistema(solicitud)
    
// Paso 3: Notificar al primer nivel de aprobación
notificarAprobador(solicitud, obtenerPrimerAprobador())
    
// Bucle para manejar los niveles de aprobación
mientras hayaMasAprobadores() {
  respuesta = esperarRespuestaAprobador()
    
  si respuesta es "Rechazado" {
    actualizarEstadoSolicitud(idSolicitud, "Rechazado")
    notificarSolicitante(idSolicitud, "Rechazado")
    retornar
  } else si respuesta es "Aprobado" y no esUltimoAprobador() {
    notificarAprobador(solicitud, obtenerSiguienteAprobador())
  } else {
    romper
  }
}
    
// Paso final: Aprobación final
actualizarEstadoSolicitud(idSolicitud, "Aprobado")
notificarSolicitante(idSolicitud, "Aprobado")
    }

# %% [markdown]
# funcion esValida(solicitud) {
#       // Implementar lógica de validación
#       // Esto podría incluir verificar la completitud de la solicitud, la autenticidad de la información, etc.
#     }
#
#     funcion registrarSolicitudEnSistema(solicitud) {
#       // Implementar integración con el sistema de gestión de solicitudes para registrar la nueva solicitud
#       // Debe retornar un identificador único para la solicitud
#     }
#
#     funcion notificarAprobador(solicitud, aprobador) {
#       // Implementar lógica para notificar al aprobador sobre la solicitud pendiente
#       // Esto podría incluir enviar un correo electrónico, una notificación en el sistema, etc.
#     }
#
#     funcion esperarRespuestaAprobador() {
#       // Implementar lógica para esperar y capturar la respuesta del aprobador
#       // Esto podría ser a través de una interfaz de usuario en el sistema de gestión de solicitudes, un correo electrónico, etc.
#     }
#
#     funcion actualizarEstadoSolicitud(idSolicitud, estado) {
#       // Implementar integración con el sistema de gestión de solicitudes para actualizar el estado de la solicitud
#     }
#
#     funcion notificarSolicitante(idSolicitud, estado) {
#       // Implementar lógica para notificar al solicitante sobre el estado final de su solicitud
#       // Esto podría incluir enviar un correo electrónico, una notificación en el sistema, etc.
#     }
#
#     ```
#
#     Este pseudo-código describe un proceso automatizado de aprobación de solicitudes, desde la validación inicial hasta la notificación final al solicitante. La solución está diseñada para integrarse con sistemas existentes, como un sistema de gestión de solicitudes, y manejar eficientemente los requisitos de datos a través de la captura y actualización de información relacionada con cada solicitud. La automatización de este proceso ayuda a reducir los tiempos de espera, mejora la transparencia y aumenta la eficiencia general del proceso.
