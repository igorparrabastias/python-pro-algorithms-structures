# %% [markdown]
# # Cuestionario de sección
#
# ### Pregunta 1: ¿Qué hace el siguiente código en Python?

# %%
for i in range(5):
    print(i)

# %% [markdown]
# a) Imprime los números del 0 al 4.
#
# b) Imprime los números del 1 al 5.
#
# c) Genera un error.
#
# d) Imprime el número 5 cinco veces.
#
# ### Pregunta 2: ¿Cómo se representa un bloque de código en Python?
#
# a) Con corchetes `{}`.
#
# b) Con la palabra clave `begin` y `end`.
#
# c) Con indentación o espacios al principio de la línea.
#
# d) Con paréntesis `()`.
#
# ### Pregunta 3: ¿Cuál es el resultado de ejecutar `a[1:4]` si `a = [0, 1, 2, 3, 4]`?
#
# a) `[0, 1, 2]`
#
# b) `[1, 2, 3]`
#
# c) `[2, 3, 4]`
#
# d) `[1, 2, 3, 4]`
#
# ### Pregunta 4: ¿Qué palabra clave se utiliza para manejar excepciones en Python?
#
# a) `try`
#
# b) `catch`
#
# c) `exception`
#
# d) `error`
#
# ### Pregunta 5: ¿Qué tipo de dato se devuelve al ejecutar `type({1, 2, 3})`?
#
# a) `list`
#
# b) `dict`
#
# c) `set`
#
# d) `tuple`
#
# ### Pregunta 6: ¿Cómo se crea una lista vacía en Python?
#
# a) `[]`
#
# b) `list()`
#
# c) Ambas respuestas son correctas.
#
# d) Ninguna de las anteriores.
#
# ### Pregunta 7: ¿Cuál es la salida del siguiente fragmento de código?

# %%
print("Hola Mundo"[-1])

# %% [markdown]
# a) `Hola Mundo`
#
# b) `o`
#
# c) `d`
#
# d) `M`
#
# ### Pregunta 8: ¿Qué hace la función `reversed()` en Python?
#
# a) Ordena una lista en orden alfabético.
#
# b) Invierte el orden de los elementos de una lista.
#
# c) Elimina todos los elementos de una lista.
#
# d) Genera un error si la lista está vacía.
#
# ### Pregunta 9: ¿Qué palabra clave permite ejecutar código independientemente de que se produzca una excepción o no?
#
# a) `finally`
#
# b) `else`
#
# c) `pass`
#
# d) `break`
#
# ### Pregunta 10: ¿Qué sucede si intentamos indexar una lista con un índice fuera de rango?
#
# a) Retorna `None`.
#
# b) Retorna el primer elemento.
#
# c) Genera una excepción `IndexError`.
#
# d) Genera una excepción `ValueError`.
#
# ### Pregunta 11: ¿Cuál es la salida del siguiente código?

# %%
def func(x):
    return x * 2

print(func(5))

# %% [markdown]
# a) `10`
#
# b) `5`
#
# c) `25`
#
# d) `funcfunc`
#
# ### Pregunta 12: ¿Cómo se representa una cadena en Python?
#
# a) Entre comillas simples `'cadena'`.
#
# b) Entre comillas dobles `"cadena"`.
#
# c) Entre triples comillas `"""cadena"""`.
#
# d) Todas las anteriores son válidas.
#
# ### Pregunta 13: ¿Qué palabra clave se usa para definir una función recursiva en Python?
#
# a) `recursive`
#
# b) `def`
#
# c) `lambda`
#
# d) `return`
#
# ### Pregunta 14: ¿Qué es el "cheat sheet" en programación?
#
# a) Una hoja con trucos para pasar un juego.
#
# b) Una guía rápida de referencia con los comandos más utilizados.
#
# c) Un programa que resuelve ejercicios automáticamente.
#
# d) Una lista de atajos de teclado.
#
# ### Pregunta 15: ¿Qué ocurre si se intenta modificar un elemento de una tupla en Python?
#
# a) La tupla se modifica sin problemas.
#
# b) Python crea una nueva tupla con la modificación.
#
# c) Se produce una excepción de tipo `TypeError`.
#
# d) La tupla se convierte automáticamente en una lista.
#
# ### Pregunta 16: ¿Qué sucede al ejecutar el siguiente código?

# %%
for i in range(3, -1, -1):
    print(i)

# %% [markdown]
# a) Se imprime una cuenta regresiva desde 3 hasta 0.
#
# b) Se imprime una cuenta regresiva desde 3 hasta 1.
#
# c) El programa entra en un bucle infinito.
#
# d) Se produce un `ValueError`.
#
# ### Pregunta 17: ¿Qué palabra clave se utiliza para declarar un error intencionalmente en Python?
#
# a) `pass`
#
# b) `error`
#
# c) `raise`
#
# d) `assert`
#
# ### Pregunta 18: ¿Cuál es la salida del siguiente fragmento de código?

# %%
def sumar(a, b):
    return a + b

resultado = sumar('Python', '3.8')
print(resultado)

# %% [markdown]
# a) `Python3.8`
#
# b) `Python 3.8`
#
# c) `Python38`
#
# d) Se produce un `TypeError`.
#
# ### Pregunta 19: ¿Cómo se puede capturar el nombre de la excepción que se ha producido en Python?
#
# a) `except Exception as e: print(e)`
#
# b) `except Exception, e: print(e)`
#
# c) `except Error as e: print(e)`
#
# d) `except Error, e: print(e)`
#
# ### Pregunta 20: ¿Qué hace la función `enumerate()` en un bucle for en Python?
#
# a) Enumera los elementos de una secuencia y los devuelve como tuplas.
#
# b) Cuenta la cantidad de elementos en la secuencia.
#
# c) Ejecuta una enumeración de tipo `int`.
#
# d) Nada, es un concepto inventado y no existe en Python.
