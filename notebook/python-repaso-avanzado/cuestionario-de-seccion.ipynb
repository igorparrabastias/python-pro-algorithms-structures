# %% [markdown]
# # Cuestionario de sección
#
# ### Pregunta 1: ¿Cuál es la principal diferencia entre un iterador y un generador en Python?
#
# a) Un iterador es una función, mientras que un generador es un objeto.
#
# b) Un generador puede producir una secuencia de valores, mientras que un iterador no puede.
#
# c) Un generador utiliza la palabra clave `yield`, mientras que un iterador no.
#
# d) No hay diferencia; son términos intercambiables.
#
# ### Pregunta 2: ¿Qué permite la declaración `with` en Python?
#
# a) Crear decoradores de manera simplificada.
#
# b) Importar librerías externas.
#
# c) Gestionar el contexto de ejecución de un bloque de código, especialmente para el manejo de recursos.
#
# d) Definir funciones anónimas.
#
# ### Pregunta 3: ¿Qué característica especial tienen los decoradores en Python?
#
# a) Permiten modificar variables globales de forma segura.
#
# b) Facilitan la creación de clases abstractas.
#
# c) Permiten modificar o ampliar el comportamiento de funciones o métodos sin cambiar su código fuente.
#
# d) Son una forma simplificada de crear iteradores.
#
# ### Pregunta 4: ¿Qué significa que las funciones en Python sean tratadas como objetos de primera clase?
#
# a) Que pueden ser creadas en tiempo de ejecución.
#
# b) Que solo pueden ser usadas como métodos de clases.
#
# c) Que pueden ser pasadas como argumentos a otras funciones, retornadas por otras funciones y asignadas a variables.
#
# d) Que tienen un espacio de memoria reservado en el sistema.
#
# ### Pregunta 5: ¿Qué es un método mágico en el contexto de las clases en Python?
#
# a) Un método que puede ser invocado sin ser definido.
#
# b) Un método que permite la sobrecarga de operadores.
#
# c) Un método que se ejecuta automáticamente al importar una clase.
#
# d) Un método que no puede ser sobrescrito.
#
# ### Pregunta 6: ¿Cuál de los siguientes conceptos NO está relacionado con la programación orientada a objetos en Python?
#
# a) Encapsulamiento
#
# b) Recursión
#
# c) Herencia
#
# d) Polimorfismo
#
# ### Pregunta 7: ¿Cómo se implementa la abstracción en Python?
#
# a) Usando decoradores exclusivamente.
#
# b) Mediante el uso de clases abstractas y métodos abstractos.
#
# c) A través de funciones anónimas.
#
# d) Aplicando generadores.
#
# ### Pregunta 8: ¿Qué característica tienen las funciones lambda en Python?
#
# a) No pueden tener más de un parámetro.
#
# b) Son una forma de implementar recursividad.
#
# c) Son funciones anónimas de una sola línea.
#
# d) No pueden ser usadas en expresiones condicionales.
#
# ### Pregunta 9: ¿Qué es un closure en Python?
#
# a) Un bloque de código que no se ejecuta hasta que no se llama.
#
# b) Una función que recuerda el valor de las variables externas incluso si ya no están en el alcance.
#
# c) Una técnica para iterar sobre secuencias.
#
# d) Un patrón de diseño para manejar excepciones.
#
# ### Pregunta 10: En el contexto de los decoradores, ¿qué es un wrapper?
#
# a) Una función que envuelve a otra función, modificando su comportamiento.
#
# b) Un tipo especial de clase para manejar excepciones.
#
# c) Un generador que facilita la iteración.
#
# d) Un objeto que almacena temporalmente datos para un iterador.
#
# ### Pregunta 11: ¿Qué hace el siguiente fragmento de código?

# %%
def decorador(func):
    def wrapper():
        print("Antes de la ejecución")
        func()
        print("Después de la ejecución")
    return wrapper

@decorador
def saluda():
    print("¡Hola!")

saluda()

# %% [markdown]
# a) Imprime "Antes de la ejecución", luego "¡Hola!" y finalmente "Después de la ejecución".
#
# b) Genera un error porque los decoradores no pueden ser usados con funciones.
#
# c) Solo imprime "¡Hola!".
#
# d) Imprime "Antes de la ejecución" y "Después de la ejecución" en un bucle infinito.
#
# ### Pregunta 12: ¿Qué característica NO corresponde a las clases abstractas en Python?
#
# a) Permiten la creación de subclases que implementan los métodos abstractos.
#
# b) Pueden ser instanciadas directamente.
#
# c) Fuerzan a las subclases a implementar métodos abstractos.
#
# d) Se utilizan para definir una interfaz común para un conjunto de subclases.
#
# ### Pregunta 13: ¿Cuál es la utilidad de la palabra clave `yield` en Python?
#
# a) Indicar el final de un bucle.
#
# b) Crear una función lambda.
#
# c) Producir valores en un generador.
#
# d) Manejar excepciones dentro de un bloque de código.
#
# ### Pregunta 14: ¿Cuál de las siguientes afirmaciones sobre el manejo de recursos con `with` en Python es verdadera?
#
# a) Solo se puede usar con archivos.
#
# b) Garantiza que los recursos sean liberados correctamente, incluso si ocurre una excepción.
#
# c) No es necesario cerrar el recurso manualmente.
#
# d) b) y c) son correctas.
#
# ### Pregunta 15: ¿Cuál es el propósito principal de las funciones lambda en Python?
#
# a) Simplificar el código al escribir funciones cortas sin necesidad de nombrarlas.
#
# b) Reemplazar completamente el uso de funciones definidas con `def`.
#
# c) Implementar recursividad de manera más eficiente.
#
# d) Crear nuevas clases de manera dinámica.
#
# ### Pregunta 16: ¿Qué se define mediante una clase en Python?
#
# a) Una secuencia de números.
#
# b) Un conjunto de reglas para el manejo de excepciones.
#
# c) Un nuevo tipo de dato que puede contener datos y funciones para operar con esos datos.
#
# d) Un decorador para funciones y métodos.
#
# ### Pregunta 17: ¿Cómo se logra el polimorfismo en Python?
#
# a) A través del uso exclusivo de funciones lambda.
#
# b) Mediante la sobrecarga de métodos en clases derivadas.
#
# c) Utilizando decoradores para cambiar el comportamiento de las funciones.
#
# d) Implementando diferentes funciones con el mismo nombre en distintas clases.
#
# ### Pregunta 18: ¿Qué hace el siguiente código?

# %%
with open('archivo.txt', 'r') as archivo:
    contenido = archivo.read()

# %% [markdown]
# a) Escribe texto en 'archivo.txt'.
#
# b) Lee el contenido de 'archivo.txt' y lo asigna a la variable `contenido`.
#
# c) Crea un nuevo archivo llamado 'archivo.txt'.
#
# d) Genera un error si 'archivo.txt' no existe.
#
# ### Pregunta 19: ¿Qué es una función de primera clase en Python?
#
# a) Una función que solo puede ser definida en la primera línea de un script.
#
# b) Una función que tiene prioridad de ejecución sobre otras
#
# c) Una función que puede ser pasada como argumento, retornada por otra función y asignada a una variable.
#
# d) Una función que no retorna valores.
#
# ### Pregunta 20: ¿Qué método especial se utiliza para inicializar objetos en las clases de Python?
#
# a) `__start__()`
#
# b) `__init__()`
#
# c) `__new__()`
#
# d) `__create__()`
